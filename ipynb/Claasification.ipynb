# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
pd.pandas.set_option('display.max_columns',None)
import seaborn as sns
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline,make_pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import OneHotEncoder,PowerTransformer,StandardScaler,MinMaxScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
import pickle
import warnings
warnings.filterwarnings(action="ignore")
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("forest_outliers_removed1")

# %%
df.head()
# Out:
#    Unnamed: 0  day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  \
# 0           0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6
# 1           1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6
# 2           2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1
# 3           3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9
# 4           4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2
#
#    ISI  BUI  FWI   Classes
# 0  1.3  3.4  0.5  not fire
# 1  1.0  3.9  0.4  not fire
# 2  0.3  2.7  0.1  not fire
# 3  0.0  1.7  0.0  not fire
# 4  1.2  3.9  0.5  not fire

# %%
df.drop(columns=['Unnamed: 0'],axis=1,inplace=True)

# %%
df['Classes']=df['Classes'].apply(lambda x:1 if x=='fire' else 0)

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI  Classes
# 0  0.5        0
# 1  0.4        0
# 2  0.1        0
# 3  0.0        0
# 4  0.5        0

# %%
X=df.drop(columns=['year','Classes'],axis=1)

# %%
y=df['Classes']

# %%
X
# Out:
#      day  month  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI
# 0      1      6           29  57  18   0.0  65.7   3.4   7.6  1.3   3.4  0.5
# 1      2      6           29  61  13   1.3  64.4   4.1   7.6  1.0   3.9  0.4
# 2      3      6           26  82  22  13.1  47.1   2.5   7.1  0.3   2.7  0.1
# 3      4      6           25  89  13   2.5  28.6   1.3   6.9  0.0   1.7  0.0
# 4      5      6           27  77  16   0.0  64.8   3.0  14.2  1.2   3.9  0.5
# ..   ...    ...          ...  ..  ..   ...   ...   ...   ...  ...   ...  ...
# 239   26      9           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5
# 240   27      9           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0
# 241   28      9           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2
# 242   29      9           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7
# 243   30      9           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5
#
# [244 rows x 12 columns]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y)

# %%
X_train.shape,X_test.shape
# Out:
# ((183, 12), (61, 12))

# %%
lr=LogisticRegression()
pipe=Pipeline([
    ('lr',lr)
])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
accuracy=accuracy_score(y_test,y_pred)

# %%
accuracy
# Out:
# 0.9836065573770492

# %%
print("confusion matrix: \n",confusion_matrix(y_test,y_pred))
print("classification report: \n",classification_report(y_test,y_pred))
# Out:
# confusion matrix:
#  [[27  0]
#  [ 1 33]]
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        27
#            1       1.00      0.97      0.99        34
#
#     accuracy                           0.98        61
#    macro avg       0.98      0.99      0.98        61
# weighted avg       0.98      0.98      0.98        61

# %%
svc=SVC()
pipe=Pipeline([
    ('svc',svc)
])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
accuracy=accuracy_score(y_test,y_pred)

# %%
accuracy
# Out:
# 0.8688524590163934

# %%
print("confusion matrix: \n",confusion_matrix(y_test,y_pred))
print("classification report: \n",classification_report(y_test,y_pred))
# Out:
# confusion matrix:
#  [[25  2]
#  [ 6 28]]
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.93      0.86        27
#            1       0.93      0.82      0.87        34
#
#     accuracy                           0.87        61
#    macro avg       0.87      0.87      0.87        61
# weighted avg       0.88      0.87      0.87        61

# %%
gaussian=GaussianNB()
pipe=Pipeline(
[
    ('gaussian',gaussian)
])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
accuracy=accuracy_score(y_test,y_pred)

# %%
accuracy
# Out:
# 0.9344262295081968

# %%
print("confusion matrix: \n",confusion_matrix(y_test,y_pred))
print("classification report: \n",classification_report(y_test,y_pred))
# Out:
# confusion matrix:
#  [[27  0]
#  [ 4 30]]
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93        27
#            1       1.00      0.88      0.94        34
#
#     accuracy                           0.93        61
#    macro avg       0.94      0.94      0.93        61
# weighted avg       0.94      0.93      0.93        61

# %%
knn=KNeighborsClassifier()
pipe=Pipeline([
    ('knn',knn)
])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
accuracy=accuracy_score(y_test,y_pred)

# %%
accuracy
# Out:
# 0.9180327868852459

# %%
print("confusion matrix: \n",confusion_matrix(y_test,y_pred))
print("classification report: \n",classification_report(y_test,y_pred))
# Out:
# confusion matrix:
#  [[25  2]
#  [ 3 31]]
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91        27
#            1       0.94      0.91      0.93        34
#
#     accuracy                           0.92        61
#    macro avg       0.92      0.92      0.92        61
# weighted avg       0.92      0.92      0.92        61

# %%
tree=DecisionTreeClassifier()
pipe=Pipeline([
    ('tree',tree)
])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
accuracy=accuracy_score(y_test,y_pred)

# %%
accuracy
# Out:
# 0.9672131147540983

# %%
print("confusion matrix: \n",confusion_matrix(y_test,y_pred))
print("classification report: \n",classification_report(y_test,y_pred))
# Out:
# confusion matrix:
#  [[26  1]
#  [ 1 33]]
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96        27
#            1       0.97      0.97      0.97        34
#
#     accuracy                           0.97        61
#    macro avg       0.97      0.97      0.97        61
# weighted avg       0.97      0.97      0.97        61

# %%
rf=RandomForestClassifier()
pipe=Pipeline([
    ('rf',rf)
])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
accuracy=accuracy_score(y_test,y_pred)

# %%
accuracy
# Out:
# 0.9836065573770492

# %%
print("confusion matrix: \n",confusion_matrix(y_test,y_pred))
print("classification report: \n",classification_report(y_test,y_pred))
# Out:
# confusion matrix:
#  [[27  0]
#  [ 1 33]]
# classification report:
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        27
#            1       1.00      0.97      0.99        34
#
#     accuracy                           0.98        61
#    macro avg       0.98      0.99      0.98        61
# weighted avg       0.98      0.98      0.98        61

# %%
import json
result = X_test.to_json(orient="records")
parsed = json.loads(result)

# %%
parsed
# Out:
# [{'day': 16,
#   'month': 8,
#   'Temperature': 36,
#   'RH': 61,
#   'Ws': 18,
#   'Rain': 0.3,
#   'FFMC': 80.2,
#   'DMC': 11.7,
#   'DC': 90.4,
#   'ISI': 2.8,
#   'BUI': 17.6,
#   'FWI': 4.2},
#  {'day': 24,
#   'month': 7,
#   'Temperature': 33,
#   'RH': 63,
#   'Ws': 17,
#   'Rain': 1.1,
#   'FFMC': 72.8,
#   'DMC': 20.9,
#   'DC': 56.6,
#   'ISI': 1.6,
#   'BUI': 21.7,
#   'FWI': 2.5},
#  {'day': 6,
#   'month': 8,
#   'Temperature': 30,
#   'RH': 54,
#   'Ws': 14,
#   'Rain': 3.1,
#   'FFMC': 70.5,
#   'DMC': 11.0,
#   'DC': 9.1,
#   'ISI': 1.3,
#   'BUI': 10.5,
#   'FWI': 0.8},
#  {'day': 10,
#   'month': 7,
#   'Temperature': 34,
#   'RH': 51,
#   'Ws': 16,
#   'Rain': 3.8,
#   'FFMC': 77.5,
#   'DMC': 8.0,
#   'DC': 9.5,
#   'ISI': 2.0,
#   'BUI': 7.7,
#   'FWI': 1.3},
#  {'day': 14,
#   'month': 6,
#   'Temperature': 27,
#   'RH': 79,
#   'Ws': 16,
#   'Rain': 0.7,
#   'FFMC': 53.4,
#   'DMC': 6.4,
#   'DC': 7.3,
#   'ISI': 0.5,
#   'BUI': 6.1,
#   'FWI': 0.3},
#  {'day': 1,
#   'month': 7,
#   'Temperature': 28,
#   'RH': 58,
#   'Ws': 18,
#   'Rain': 2.2,
#   'FFMC': 63.7,
#   'DMC': 3.2,
#   'DC': 8.5,
#   'ISI': 1.2,
#   'BUI': 3.3,
#   'FWI': 0.5},
#  {'day': 12,
#   'month': 6,
#   'Temperature': 27,
#   'RH': 58,
#   'Ws': 17,
#   'Rain': 0.0,
#   'FFMC': 88.9,
#   'DMC': 21.3,
#   'DC': 37.8,
#   'ISI': 8.7,
#   'BUI': 21.2,
#   'FWI': 12.9},
#  {'day': 14,
#   'month': 8,
#   'Temperature': 33,
#   'RH': 66,
#   'Ws': 14,
#   'Rain': 0.0,
#   'FFMC': 87.0,
#   'DMC': 21.7,
#   'DC': 94.7,
#   'ISI': 5.7,
#   'BUI': 27.2,
#   'FWI': 10.6},
#  {'day': 26,
#   'month': 6,
#   'Temperature': 36,
#   'RH': 62,
#   'Ws': 16,
#   'Rain': 0.0,
#   'FFMC': 87.8,
#   'DMC': 16.5,
#   'DC': 34.5,
#   'ISI': 7.0,
#   'BUI': 16.4,
#   'FWI': 9.5},
#  {'day': 9,
#   'month': 6,
#   'Temperature': 27,
#   'RH': 59,
#   'Ws': 18,
#   'Rain': 0.1,
#   'FFMC': 78.1,
#   'DMC': 8.5,
#   'DC': 14.7,
#   'ISI': 2.4,
#   'BUI': 8.3,
#   'FWI': 1.9},
#  {'day': 16,
#   'month': 7,
#   'Temperature': 28,
#   'RH': 76,
#   'Ws': 21,
#   'Rain': 0.0,
#   'FFMC': 72.6,
#   'DMC': 7.0,
#   'DC': 25.5,
#   'ISI': 0.7,
#   'BUI': 8.3,
#   'FWI': 0.4},
#  {'day': 3,
#   'month': 9,
#   'Temperature': 28,
#   'RH': 75,
#   'Ws': 16,
#   'Rain': 0.0,
#   'FFMC': 82.2,
#   'DMC': 4.4,
#   'DC': 24.3,
#   'ISI': 3.3,
#   'BUI': 6.0,
#   'FWI': 2.5},
#  {'day': 17,
#   'month': 9,
#   'Temperature': 34,
#   'RH': 44,
#   'Ws': 12,
#   'Rain': 0.0,
#   'FFMC': 92.5,
#   'DMC': 25.2,
#   'DC': 63.3,
#   'ISI': 11.2,
#   'BUI': 26.2,
#   'FWI': 17.5},
#  {'day': 17,
#   'month': 9,
#   'Temperature': 31,
#   'RH': 52,
#   'Ws': 14,
#   'Rain': 0.0,
#   'FFMC': 87.7,
#   'DMC': 6.4,
#   'DC': 24.3,
#   'ISI': 6.2,
#   'BUI': 7.7,
#   'FWI': 5.9},
#  {'day': 26,
#   'month': 9,
#   'Temperature': 31,
#   'RH': 54,
#   'Ws': 11,
#   'Rain': 0.0,
#   'FFMC': 82.0,
#   'DMC': 6.0,
#   'DC': 16.3,
#   'ISI': 2.5,
#   'BUI': 6.2,
#   'FWI': 1.7},
#  {'day': 31,
#   'month': 7,
#   'Temperature': 37,
#   'RH': 55,
#   'Ws': 15,
#   'Rain': 0.0,
#   'FFMC': 89.3,
#   'DMC': 28.3,
#   'DC': 67.2,
#   'ISI': 8.3,
#   'BUI': 28.3,
#   'FWI': 14.5},
#  {'day': 3,
#   'month': 6,
#   'Temperature': 29,
#   'RH': 80,
#   'Ws': 14,
#   'Rain': 2.0,
#   'FFMC': 48.7,
#   'DMC': 2.2,
#   'DC': 7.6,
#   'ISI': 0.3,
#   'BUI': 2.6,
#   'FWI': 0.1},
#  {'day': 2,
#   'month': 6,
#   'Temperature': 29,
#   'RH': 61,
#   'Ws': 13,
#   'Rain': 1.3,
#   'FFMC': 64.4,
#   'DMC': 4.1,
#   'DC': 7.6,
#   'ISI': 1.0,
#   'BUI': 3.9,
#   'FWI': 0.4},
#  {'day': 21,
#   'month': 6,
#   'Temperature': 32,
#   'RH': 55,
#   'Ws': 14,
#   'Rain': 0.0,
#   'FFMC': 86.2,
#   'DMC': 8.3,
#   'DC': 18.4,
#   'ISI': 5.0,
#   'BUI': 8.2,
#   'FWI': 4.9},
#  {'day': 5,
#   'month': 8,
#   'Temperature': 34,
#   'RH': 65,
#   'Ws': 13,
#   'Rain': 0.0,
#   'FFMC': 86.8,
#   'DMC': 11.1,
#   'DC': 29.7,
#   'ISI': 5.2,
#   'BUI': 11.5,
#   'FWI': 6.1},
#  {'day': 31,
#   'month': 8,
#   'Temperature': 28,
#   'RH': 80,
#   'Ws': 21,
#   'Rain': 16.8,
#   'FFMC': 52.5,
#   'DMC': 8.7,
#   'DC': 8.7,
#   'ISI': 0.6,
#   'BUI': 8.3,
#   'FWI': 0.3},
#  {'day': 7,
#   'month': 8,
#   'Temperature': 34,
#   'RH': 63,
#   'Ws': 13,
#   'Rain': 2.9,
#   'FFMC': 69.7,
#   'DMC': 7.2,
#   'DC': 9.8,
#   'ISI': 1.2,
#   'BUI': 6.9,
#   'FWI': 0.6},
#  {'day': 5,
#   'month': 9,
#   'Temperature': 29,
#   'RH': 75,
#   'Ws': 16,
#   'Rain': 0.0,
#   'FFMC': 80.8,
#   'DMC': 3.4,
#   'DC': 24.0,
#   'ISI': 2.8,
#   'BUI': 5.1,
#   'FWI': 1.7},
#  {'day': 27,
#   'month': 7,
#   'Temperature': 36,
#   'RH': 48,
#   'Ws': 13,
#   'Rain': 0.0,
#   'FFMC': 90.3,
#   'DMC': 22.2,
#   'DC': 108.5,
#   'ISI': 8.7,
#   'BUI': 29.4,
#   'FWI': 15.3},
#  {'day': 17,
#   'month': 7,
#   'Temperature': 32,
#   'RH': 81,
#   'Ws': 17,
#   'Rain': 0.0,
#   'FFMC': 84.6,
#   'DMC': 21.1,
#   'DC': 42.3,
#   'ISI': 4.7,
#   'BUI': 20.9,
#   'FWI': 7.7},
#  {'day': 6,
#   'month': 6,
#   'Temperature': 35,
#   'RH': 54,
#   'Ws': 11,
#   'Rain': 0.1,
#   'FFMC': 83.7,
#   'DMC': 8.4,
#   'DC': 26.3,
#   'ISI': 3.1,
#   'BUI': 9.3,
#   'FWI': 3.1},
#  {'day': 31,
#   'month': 8,
#   'Temperature': 30,
#   'RH': 59,
#   'Ws': 19,
#   'Rain': 0.0,
#   'FFMC': 89.1,
#   'DMC': 27.8,
#   'DC': 168.2,
#   'ISI': 9.8,
#   'BUI': 39.3,
#   'FWI': 19.4},
#  {'day': 4,
#   'month': 6,
#   'Temperature': 30,
#   'RH': 64,
#   'Ws': 14,
#   'Rain': 0.0,
#   'FFMC': 79.4,
#   'DMC': 5.2,
#   'DC': 15.4,
#   'ISI': 2.2,
#   'BUI': 5.6,
#   'FWI': 1.0},
#  {'day': 6,
#   'month': 6,
#   'Temperature': 31,
#   'RH': 67,
#   'Ws': 14,
#   'Rain': 0.0,
#   'FFMC': 82.6,
#   'DMC': 5.8,
#   'DC': 22.2,
#   'ISI': 3.1,
#   'BUI': 7.0,
#   'FWI': 2.5},
#  {'day': 15,
#   'month': 6,
#   'Temperature': 28,
#   'RH': 80,
#   'Ws': 17,
#   'Rain': 3.1,
#   'FFMC': 49.4,
#   'DMC': 3.0,
#   'DC': 7.4,
#   'ISI': 0.4,
#   'BUI': 3.0,
#   'FWI': 0.1},
#  {'day': 24,
#   'month': 8,
#   'Temperature': 35,
#   'RH': 38,
#   'Ws': 15,
#   'Rain': 0.0,
#   'FFMC': 92.1,
#   'DMC': 51.3,
#   'DC': 147.7,
#   'ISI': 12.2,
#   'BUI': 54.9,
#   'FWI': 26.9},
#  {'day': 10,
#   'month': 6,
#   'Temperature': 30,
#   'RH': 41,
#   'Ws': 15,
#   'Rain': 0.0,
#   'FFMC': 89.4,
#   'DMC': 13.3,
#   'DC': 22.5,
#   'ISI': 8.4,
#   'BUI': 13.1,
#   'FWI': 10.0},
#  {'day': 19,
#   'month': 9,
#   'Temperature': 29,
#   'RH': 57,
#   'Ws': 14,
#   'Rain': 0.0,
#   'FFMC': 89.3,
#   'DMC': 12.5,
#   'DC': 41.3,
#   'ISI': 7.8,
#   'BUI': 14.2,
#   'FWI': 9.7},
#  {'day': 22,
#   'month': 6,
#   'Temperature': 33,
#   'RH': 46,
#   'Ws': 14,
#   'Rain': 1.1,
#   'FFMC': 78.3,
#   'DMC': 8.1,
#   'DC': 8.3,
#   'ISI': 1.9,
#   'BUI': 7.7,
#   'FWI': 1.2},
#  {'day': 24,
#   'month': 6,
#   'Temperature': 35,
#   'RH': 68,
#   'Ws': 16,
#   'Rain': 0.0,
#   'FFMC': 85.3,
#   'DMC': 10.0,
#   'DC': 17.0,
#   'ISI': 4.9,
#   'BUI': 9.9,
#   'FWI': 5.3},
#  {'day': 23,
#   'month': 8,
#   'Temperature': 36,
#   'RH': 43,
#   'Ws': 16,
#   'Rain': 0.0,
#   'FFMC': 91.2,
#   'DMC': 46.1,
#   'DC': 137.7,
#   'ISI': 11.5,
#   'BUI': 50.2,
#   'FWI': 24.5},
#  {'day': 5,
#   'month': 6,
#   'Temperature': 27,
#   'RH': 77,
#   'Ws': 16,
#   'Rain': 0.0,
#   'FFMC': 64.8,
#   'DMC': 3.0,
#   'DC': 14.2,
#   'ISI': 1.2,
#   'BUI': 3.9,
#   'FWI': 0.5},
#  {'day': 21,
#   'month': 7,
#   'Temperature': 33,
#   'RH': 70,
#   'Ws': 17,
#   'Rain': 0.0,
#   'FFMC': 85.4,
#   'DMC': 18.5,
#   'DC': 71.5,
#   'ISI': 5.2,
#   'BUI': 22.4,
#   'FWI': 8.8},
#  {'day': 7,
#   'month': 9,
#   'Temperature': 31,
#   'RH': 71,
#   'Ws': 17,
#   'Rain': 0.3,
#   'FFMC': 69.6,
#   'DMC': 3.2,
#   'DC': 30.1,
#   'ISI': 1.5,
#   'BUI': 5.1,
#   'FWI': 0.6},
#  {'day': 6,
#   'month': 7,
#   'Temperature': 35,
#   'RH': 42,
#   'Ws': 15,
#   'Rain': 0.3,
#   'FFMC': 84.7,
#   'DMC': 15.5,
#   'DC': 45.1,
#   'ISI': 4.3,
#   'BUI': 16.7,
#   'FWI': 6.3},
#  {'day': 13,
#   'month': 7,
#   'Temperature': 39,
#   'RH': 45,
#   'Ws': 13,
#   'Rain': 0.6,
#   'FFMC': 85.2,
#   'DMC': 11.3,
#   'DC': 10.4,
#   'ISI': 4.2,
#   'BUI': 10.9,
#   'FWI': 4.7},
#  {'day': 20,
#   'month': 6,
#   'Temperature': 30,
#   'RH': 80,
#   'Ws': 16,
#   'Rain': 0.4,
#   'FFMC': 59.8,
#   'DMC': 3.4,
#   'DC': 27.1,
#   'ISI': 0.9,
#   'BUI': 5.1,
#   'FWI': 0.4},
#  {'day': 2,
#   'month': 7,
#   'Temperature': 33,
#   'RH': 48,
#   'Ws': 16,
#   'Rain': 0.0,
#   'FFMC': 87.6,
#   'DMC': 7.9,
#   'DC': 17.8,
#   'ISI': 6.8,
#   'BUI': 7.8,
#   'FWI': 6.4},
#  {'day': 21,
#   'month': 7,
#   'Temperature': 36,
#   'RH': 29,
#   'Ws': 18,
#   'Rain': 0.0,
#   'FFMC': 93.9,
#   'DMC': 39.6,
#   'DC': 80.6,
#   'ISI': 18.5,
#   'BUI': 39.5,
#   'FWI': 27.3875},
#  {'day': 13,
#   'month': 6,
#   'Temperature': 27,
#   'RH': 84,
#   'Ws': 21,
#   'Rain': 1.2,
#   'FFMC': 50.0,
#   'DMC': 6.7,
#   'DC': 17.0,
#   'ISI': 0.5,
#   'BUI': 6.7,
#   'FWI': 0.2},
#  {'day': 31,
#   'month': 7,
#   'Temperature': 35,
#   'RH': 64,
#   'Ws': 17,
#   'Rain': 0.0,
#   'FFMC': 87.2,
#   'DMC': 31.9,
#   'DC': 145.7,
#   'ISI': 6.8,
#   'BUI': 41.2,
#   'FWI': 15.7},
#  {'day': 9,
#   'month': 9,
#   'Temperature': 30,
#   'RH': 77,
#   'Ws': 15,
#   'Rain': 1.0,
#   'FFMC': 56.1,
#   'DMC': 2.1,
#   'DC': 8.4,
#   'ISI': 0.7,
#   'BUI': 2.6,
#   'FWI': 0.2},
#  {'day': 14,
#   'month': 9,
#   'Temperature': 28,
#   'RH': 81,
#   'Ws': 15,
#   'Rain': 0.0,
#   'FFMC': 84.6,
#   'DMC': 12.6,
#   'DC': 41.5,
#   'ISI': 4.3,
#   'BUI': 14.3,
#   'FWI': 5.7},
#  {'day': 3,
#   'month': 9,
#   'Temperature': 25,
#   'RH': 78,
#   'Ws': 15,
#   'Rain': 3.8,
#   'FFMC': 42.6,
#   'DMC': 1.2,
#   'DC': 7.5,
#   'ISI': 0.1,
#   'BUI': 1.7,
#   'FWI': 0.0},
#  {'day': 15,
#   'month': 6,
#   'Temperature': 28,
#   'RH': 90,
#   'Ws': 15,
#   'Rain': 0.0,
#   'FFMC': 66.8,
#   'DMC': 7.2,
#   'DC': 14.7,
#   'ISI': 1.2,
#   'BUI': 7.1,
#   'FWI': 0.6},
#  {'day': 18,
#   'month': 7,
#   'Temperature': 31,
#   'RH': 68,
#   'Ws': 14,
#   'Rain': 0.0,
#   'FFMC': 85.4,
#   'DMC': 12.1,
#   'DC': 43.1,
#   'ISI': 4.6,
#   'BUI': 14.2,
#   'FWI': 6.0},
#  {'day': 25,
#   'month': 8,
#   'Temperature': 35,
#   'RH': 60,
#   'Ws': 15,
#   'Rain': 0.0,
#   'FFMC': 88.9,
#   'DMC': 43.9,
#   'DC': 181.3,
#   'ISI': 8.2,
#   'BUI': 54.7,
#   'FWI': 20.3},
#  {'day': 8,
#   'month': 9,
#   'Temperature': 30,
#   'RH': 73,
#   'Ws': 17,
#   'Rain': 0.9,
#   'FFMC': 62.0,
#   'DMC': 2.6,
#   'DC': 8.4,
#   'ISI': 1.1,
#   'BUI': 3.0,
#   'FWI': 0.4},
#  {'day': 4,
#   'month': 8,
#   'Temperature': 38,
#   'RH': 35,
#   'Ws': 15,
#   'Rain': 0.0,
#   'FFMC': 93.8,
#   'DMC': 23.0,
#   'DC': 42.7,
#   'ISI': 15.7,
#   'BUI': 22.9,
#   'FWI': 20.9},
#  {'day': 18,
#   'month': 9,
#   'Temperature': 32,
#   'RH': 49,
#   'Ws': 11,
#   'Rain': 0.0,
#   'FFMC': 89.4,
#   'DMC': 9.8,
#   'DC': 33.1,
#   'ISI': 6.8,
#   'BUI': 11.3,
#   'FWI': 7.7},
#  {'day': 1,
#   'month': 8,
#   'Temperature': 38,
#   'RH': 52,
#   'Ws': 14,
#   'Rain': 0.0,
#   'FFMC': 78.3,
#   'DMC': 4.4,
#   'DC': 10.5,
#   'ISI': 2.0,
#   'BUI': 4.4,
#   'FWI': 0.8},
#  {'day': 19,
#   'month': 7,
#   'Temperature': 35,
#   'RH': 59,
#   'Ws': 17,
#   'Rain': 0.0,
#   'FFMC': 88.1,
#   'DMC': 12.0,
#   'DC': 52.8,
#   'ISI': 7.7,
#   'BUI': 18.2,
#   'FWI': 10.9},
#  {'day': 24,
#   'month': 7,
#   'Temperature': 28,
#   'RH': 78,
#   'Ws': 16,
#   'Rain': 0.1,
#   'FFMC': 70.0,
#   'DMC': 9.6,
#   'DC': 79.7,
#   'ISI': 1.4,
#   'BUI': 14.7,
#   'FWI': 1.3},
#  {'day': 1,
#   'month': 9,
#   'Temperature': 29,
#   'RH': 86,
#   'Ws': 16,
#   'Rain': 0.0,
#   'FFMC': 37.9,
#   'DMC': 0.9,
#   'DC': 8.2,
#   'ISI': 0.1,
#   'BUI': 1.4,
#   'FWI': 0.0},
#  {'day': 26,
#   'month': 8,
#   'Temperature': 31,
#   'RH': 78,
#   'Ws': 18,
#   'Rain': 0.0,
#   'FFMC': 85.8,
#   'DMC': 45.6,
#   'DC': 190.6,
#   'ISI': 4.7,
#   'BUI': 57.1,
#   'FWI': 13.7},
#  {'day': 3,
#   'month': 7,
#   'Temperature': 32,
#   'RH': 76,
#   'Ws': 20,
#   'Rain': 0.7,
#   'FFMC': 63.1,
#   'DMC': 2.6,
#   'DC': 9.2,
#   'ISI': 1.3,
#   'BUI': 3.0,
#   'FWI': 0.5}]

# %%
pickle.dump(pipe,open('pipe_class2.pkl','wb'))

# %%
# !pip install pymongo
# Out:
# Collecting pymongo
#   Using cached pymongo-4.7.2-cp311-cp311-win_amd64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Using cached dnspython-2.6.1-py3-none-any.whl.metadata (5.8 kB)
# Using cached pymongo-4.7.2-cp311-cp311-win_amd64.whl (484 kB)
# Using cached dnspython-2.6.1-py3-none-any.whl (307 kB)
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.6.1 pymongo-4.7.2

# %%
import certifi

# %%
import pymongo
client = pymongo.MongoClient("mongodb+srv://tallojiharshith:tallojiharshith@cluster0.pyu7rs3.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0",tlsCAFile=certifi.where())

# %%
db = client.forest_fires
print(db)
# Out:
# Database(MongoClient(host=['ac-pqgccm2-shard-00-01.pyu7rs3.mongodb.net:27017', 'ac-pqgccm2-shard-00-02.pyu7rs3.mongodb.net:27017', 'ac-pqgccm2-shard-00-00.pyu7rs3.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='Cluster0', authsource='admin', replicaset='atlas-x2ptah-shard-0', tls=True, tlscafile='C:\\Anaconda\\Lib\\site-packages\\certifi\\cacert.pem'), 'forest_fires')

# %%
coll = db['classification_batch']

# %%
dict_test = {'day': 24, 'month': 6, 'RH': 68, 'Ws': 16, 'Rain': 0, 'FFMC': 85, 'DMC': 10, 'DC': 17,
                 'ISI': 4, 'BUI': 9, 'FWI': 5.3, 'classes': 0}

# %%
db.list_collection_names()
# Out:
# []

# %%
coll.insert_many(parsed)
# Out:
# InsertManyResult([ObjectId('664c90c33a203086c21f0b4f'), ObjectId('664c90c33a203086c21f0b50'), ObjectId('664c90c33a203086c21f0b51'), ObjectId('664c90c33a203086c21f0b52'), ObjectId('664c90c33a203086c21f0b53'), ObjectId('664c90c33a203086c21f0b54'), ObjectId('664c90c33a203086c21f0b55'), ObjectId('664c90c33a203086c21f0b56'), ObjectId('664c90c33a203086c21f0b57'), ObjectId('664c90c33a203086c21f0b58'), ObjectId('664c90c33a203086c21f0b59'), ObjectId('664c90c33a203086c21f0b5a'), ObjectId('664c90c33a203086c21f0b5b'), ObjectId('664c90c33a203086c21f0b5c'), ObjectId('664c90c33a203086c21f0b5d'), ObjectId('664c90c33a203086c21f0b5e'), ObjectId('664c90c33a203086c21f0b5f'), ObjectId('664c90c33a203086c21f0b60'), ObjectId('664c90c33a203086c21f0b61'), ObjectId('664c90c33a203086c21f0b62'), ObjectId('664c90c33a203086c21f0b63'), ObjectId('664c90c33a203086c21f0b64'), ObjectId('664c90c33a203086c21f0b65'), ObjectId('664c90c33a203086c21f0b66'), ObjectId('664c90c33a203086c21f0b67'), ObjectId('664c90c33a203086c21f0b68'), ObjectId('664c90c33a203086c21f0b69'), ObjectId('664c90c33a203086c21f0b6a'), ObjectId('664c90c33a203086c21f0b6b'), ObjectId('664c90c33a203086c21f0b6c'), ObjectId('664c90c33a203086c21f0b6d'), ObjectId('664c90c33a203086c21f0b6e'), ObjectId('664c90c33a203086c21f0b6f'), ObjectId('664c90c33a203086c21f0b70'), ObjectId('664c90c33a203086c21f0b71'), ObjectId('664c90c33a203086c21f0b72'), ObjectId('664c90c33a203086c21f0b73'), ObjectId('664c90c33a203086c21f0b74'), ObjectId('664c90c33a203086c21f0b75'), ObjectId('664c90c33a203086c21f0b76'), ObjectId('664c90c33a203086c21f0b77'), ObjectId('664c90c33a203086c21f0b78'), ObjectId('664c90c33a203086c21f0b79'), ObjectId('664c90c33a203086c21f0b7a'), ObjectId('664c90c33a203086c21f0b7b'), ObjectId('664c90c33a203086c21f0b7c'), ObjectId('664c90c33a203086c21f0b7d'), ObjectId('664c90c33a203086c21f0b7e'), ObjectId('664c90c33a203086c21f0b7f'), ObjectId('664c90c33a203086c21f0b80'), ObjectId('664c90c33a203086c21f0b81'), ObjectId('664c90c33a203086c21f0b82'), ObjectId('664c90c33a203086c21f0b83'), ObjectId('664c90c33a203086c21f0b84'), ObjectId('664c90c33a203086c21f0b85'), ObjectId('664c90c33a203086c21f0b86'), ObjectId('664c90c33a203086c21f0b87'), ObjectId('664c90c33a203086c21f0b88'), ObjectId('664c90c33a203086c21f0b89'), ObjectId('664c90c33a203086c21f0b8a'), ObjectId('664c90c33a203086c21f0b8b')], acknowledged=True)

# %%
pickle_model = pickle.load(open('pipe_class2.pkl','rb'))

# %%
dict_test ={'day':1, 'month':6, 'Temperature':26,'RH':57, 'Ws':18.0, 'Rain':0.00, 'FFMC':65.7000,
       'DMC':3.4, 'DC':7.6, 'ISI':1.3, 'BUI':3.4, 'FWI':0.5}

# %%
list(dict_test.values())
# Out:
# [1, 6, 26, 57, 18.0, 0.0, 65.7, 3.4, 7.6, 1.3, 3.4, 0.5]

# %%
input = np.array(list(dict_test.values())).reshape(1,12)

# %%
pipe.predict(input)[0]
# Out:
# 0
